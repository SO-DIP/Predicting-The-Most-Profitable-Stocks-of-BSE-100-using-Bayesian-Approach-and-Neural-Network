# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout


# Download the data
df = pd.read_csv("PIDILITE.csv" , index_col = 'Date', parse_dates = ['Date'])
df =df[::-1]

# %%
df
# Out:
#             Open Price  High Price  Low Price  Close Price          WAP  \
# Date
# 2018-01-01      902.50      909.20     899.30       900.90   903.546550
# 2018-01-02      903.35      903.90     877.40       888.75   886.138504
# 2018-01-03      888.75      914.80     888.75       910.95   907.192941
# 2018-01-04      915.00      918.35     905.00       907.55   911.833935
# 2018-01-05      901.05      913.65     901.05       910.70   909.545704
# ...                ...         ...        ...          ...          ...
# 2022-12-26     2470.05     2528.90    2465.00      2512.20  2507.034677
# 2022-12-27     2527.85     2545.95    2510.00      2536.70  2529.484966
# 2022-12-28     2548.95     2632.85    2527.50      2588.60  2582.682588
# 2022-12-29     2589.90     2629.65    2541.05      2609.85  2574.797291
# 2022-12-30     2618.95     2618.95    2542.80      2550.65  2576.688498
#
#             No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# Date
# 2018-01-01         23491            714              21225212
# 2018-01-02         61211           1621              54241424
# 2018-01-03         34933           1137              31690971
# 2018-01-04         38226            939              34855764
# 2018-01-05         23291            789              21184229
# ...                  ...            ...                   ...
# 2022-12-26          8507           1673              21327344
# 2022-12-27          5654           1187              14301708
# 2022-12-28          8626           1405              22278220
# 2022-12-29         20300           3057              52268385
# 2022-12-30         20597           3973              53072053
#
#             Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# Date
# 2018-01-01                  9077                      38.64             9.90
# 2018-01-02                 13276                      21.69            26.50
# 2018-01-03                  7919                      22.67            26.05
# 2018-01-04                  7357                      19.25            13.35
# 2018-01-05                  7923                      34.02            12.60
# ...                          ...                        ...              ...
# 2022-12-26                  3968                      46.64            63.90
# 2022-12-27                  1796                      31.77            35.95
# 2022-12-28                  2501                      28.99           105.35
# 2022-12-29                  7739                      38.12            88.60
# 2022-12-30                  7390                      35.88            76.15
#
#             Spread Close-Open
# Date
# 2018-01-01              -1.60
# 2018-01-02             -14.60
# 2018-01-03              22.20
# 2018-01-04              -7.45
# 2018-01-05               9.65
# ...                       ...
# 2022-12-26              42.15
# 2022-12-27               8.85
# 2022-12-28              39.65
# 2022-12-29              19.95
# 2022-12-30             -68.30
#
# [1239 rows x 12 columns]

# %%
df = df['Close Price']

# %%
# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(df).reshape(-1, 1))

# Split data into training and testing sets
training_size = int(len(scaled_data) * 0.8)
test_size = len(scaled_data) - training_size
train_data, test_data = scaled_data[0:training_size,:], scaled_data[training_size:len(scaled_data),:]

# Define the look-back period
look_back = 60

# Define function to create dataset with look-back period
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        X.append(dataset[i-look_back:i, 0])
        Y.append(dataset[i, 0])
    return np.array(X), np.array(Y)

# Create training and testing datasets
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# %%
# Reshape input data to be suitable for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and fit model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=100, batch_size=32)

# Make predictions on test set
y_pred = model.predict(X_test)

# Invert predictions and actual values from scaling
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform([y_test])

# Calculate and print RMSE
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print(f"Root Mean Square Error: {rmse:.2f}")

# Plot actual and predicted values
plt.figure(figsize=(12,8))
plt.plot(y_test.flatten(), label="Actual")
plt.plot(y_pred.flatten(), label="Predicted")
plt.legend(fontsize=12)
plt.xlabel("Days", fontsize=12)
plt.ylabel("Closing Price", fontsize=12)
plt.title("PIDILITE Industries Stock Price Prediction", fontsize=16)
plt.show()
# Out:
# Epoch 1/100
# 30/30 [==============================] - 7s 43ms/step - loss: 0.0203
# Epoch 2/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0027
# Epoch 3/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0024
# Epoch 4/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0033
# Epoch 5/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0025
# Epoch 6/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0024
# Epoch 7/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0021
# Epoch 8/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0022
# Epoch 9/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0025
# Epoch 10/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0020
# Epoch 11/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0020
# Epoch 12/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0020
# Epoch 13/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0023
# Epoch 14/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0021
# Epoch 15/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0018
# Epoch 16/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0017
# Epoch 17/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0018
# Epoch 18/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0017
# Epoch 19/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0019
# Epoch 20/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0018
# Epoch 21/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0018
# Epoch 22/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0015
# Epoch 23/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0017
# Epoch 24/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0017
# Epoch 25/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0016
# Epoch 26/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0016
# Epoch 27/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0018
# Epoch 28/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0014
# Epoch 29/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0016
# Epoch 30/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0015
# Epoch 31/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0016
# Epoch 32/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0014
# Epoch 33/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0014
# Epoch 34/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0013
# Epoch 35/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0014
# Epoch 36/100
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0013
# Epoch 37/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0015
# Epoch 38/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0013
# Epoch 39/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0018
# Epoch 40/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 41/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 42/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0012
# Epoch 43/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0014
# Epoch 44/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0024
# Epoch 45/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 46/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0011
# Epoch 47/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 48/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 49/100
# 30/30 [==============================] - 1s 47ms/step - loss: 9.9789e-04
# Epoch 50/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 51/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0010
# Epoch 52/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0015
# Epoch 53/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 54/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 55/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 56/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 57/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0010
# Epoch 58/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0010
# Epoch 59/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 60/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 61/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0011
# Epoch 62/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.9503e-04
# Epoch 63/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.8423e-04
# Epoch 64/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0011
# Epoch 65/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0010
# Epoch 66/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0012
# Epoch 67/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.7378e-04
# Epoch 68/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0010
# Epoch 69/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.5368e-04
# Epoch 70/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.6746e-04
# Epoch 71/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.5438e-04
# Epoch 72/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.1554e-04
# Epoch 73/100
# 30/30 [==============================] - 1s 47ms/step - loss: 8.8845e-04
# Epoch 74/100
# 30/30 [==============================] - 1s 47ms/step - loss: 9.5969e-04
# Epoch 75/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.7643e-04
# Epoch 76/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.1012e-04
# Epoch 77/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.1706e-04
# Epoch 78/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.4612e-04
# Epoch 79/100
# 30/30 [==============================] - 1s 47ms/step - loss: 9.0984e-04
# Epoch 80/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.3273e-04
# Epoch 81/100
# 30/30 [==============================] - 1s 48ms/step - loss: 7.8191e-04
# Epoch 82/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0012
# Epoch 83/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0011
# Epoch 84/100
# 30/30 [==============================] - 1s 49ms/step - loss: 8.1545e-04
# Epoch 85/100
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0010
# Epoch 86/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.1673e-04
# Epoch 87/100
# 30/30 [==============================] - 1s 49ms/step - loss: 7.8847e-04
# Epoch 88/100
# 30/30 [==============================] - 1s 50ms/step - loss: 7.7654e-04
# Epoch 89/100
# 30/30 [==============================] - 1s 48ms/step - loss: 7.5984e-04
# Epoch 90/100
# 30/30 [==============================] - 1s 48ms/step - loss: 8.6253e-04
# Epoch 91/100
# 30/30 [==============================] - 1s 49ms/step - loss: 8.5327e-04
# Epoch 92/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0010
# Epoch 93/100
# 30/30 [==============================] - 1s 48ms/step - loss: 9.6963e-04
# Epoch 94/100
# 30/30 [==============================] - 1s 47ms/step - loss: 7.3227e-04
# Epoch 95/100
# 30/30 [==============================] - 1s 48ms/step - loss: 7.6595e-04
# Epoch 96/100
# 30/30 [==============================] - 1s 47ms/step - loss: 7.5413e-04
# Epoch 97/100
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0010
# Epoch 98/100
# 30/30 [==============================] - 1s 45ms/step - loss: 7.4535e-04
# Epoch 99/100
# 30/30 [==============================] - 1s 43ms/step - loss: 6.7023e-04
# Epoch 100/100
# 30/30 [==============================] - 1s 43ms/step - loss: 7.8924e-04
# 6/6 [==============================] - 1s 14ms/step
# Root Mean Square Error: 325.39

# %%
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('Mean Absolute Percentage Error:', mape)
# Out:
# Mean Absolute Percentage Error: 10.660029489718951
